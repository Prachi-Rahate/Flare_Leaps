# %%
import lightkurve as lk
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
search_result = lk.search_lightcurve('TIC 271698144')
search_result[0]
# Out:
# SearchResult containing 1 data products.
#
#  #     mission     year author exptime target_name distance
#                                   s                 arcsec
# --- -------------- ---- ------ ------- ----------- --------
#   0 TESS Sector 01 2018   SPOC     120   271698144      0.0

# %%
lc = search_result[0].download()
# Out:
# WARNING: UnitsWarning: 'BJD - 2457000, days' did not parse as fits unit: At col 0, Unit 'BJD' not supported by the FITS standard.  If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'e-/s' did not parse as fits unit: At col 0, Unit 'e' not supported by the FITS standard.  If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'pixels' did not parse as fits unit: At col 0, Unit 'pixels' not supported by the FITS standard. Did you mean pixel? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]

# %%
#lc.PDCSAP_FLUX.plot()
#plt.savefig("./TIC_353898013/flare_353898013")

# %% [markdown]
# # remove outliers and nan values
#
# -

# %%
#remove outliers and nan values

lc1 = lc.remove_nans()#.remove_outliers()
#print(lc)
lc1 = (lc1["time", "flux", "flux_err"])
print(lc1)
# Out:
#        time             flux         flux_err
#                     electron / s   electron / s
# ------------------ -------------- --------------
# 1325.2963109577513  1.3249740e+03  6.8881454e+00
# 1325.2976998207625  1.3259080e+03  6.8925900e+00
#  1325.299088683832  1.3143271e+03  6.8844318e+00
# 1325.3004775469012  1.3227627e+03  6.8828244e+00
# 1325.3018664100289  1.3241494e+03  6.8927927e+00
# 1325.3032552730983  1.3191639e+03  6.8898010e+00
# 1325.3046441361676  1.3233344e+03  6.8885279e+00
#  1325.306032999295  1.3166780e+03  6.8856878e+00
# 1325.3074218624226  1.3154429e+03  6.8854027e+00
#  1325.308810725492  1.3200308e+03  6.8934374e+00
#                ...            ...            ...
# 1353.1638602656612  1.3220465e+03  6.9277053e+00
# 1353.1652491216305  1.3257135e+03  6.9424052e+00
# 1353.1666379776007  1.3189886e+03  6.9370165e+00
# 1353.1680268335772  1.3200209e+03  6.9296165e+00
#  1353.169415689546  1.3248441e+03  6.9315414e+00
# 1353.1708045455089  1.3213290e+03  6.9402156e+00
#  1353.172193401479  1.3275897e+03  6.9552169e+00
#  1353.173582257449  1.3317167e+03  6.9512043e+00
# 1353.1749711134112  1.3262686e+03  6.9358740e+00
# 1353.1763599693725  1.3089333e+03  6.9239273e+00
# Length = 18279 rows

# %%
lc1.plot()
# Out:
# <AxesSubplot:xlabel='Time - 2457000 [BTJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %%
#normalize

n_lc = lc1.normalize()
n_lc.plot()
# Out:
# <AxesSubplot:xlabel='Time - 2457000 [BTJD days]', ylabel='Normalized Flux'>

# %%
###lc.to_fits(path='./TIC_233547261/TIC_233547261.fits', overwrite=True)

# %%
#n_lc.to_csv(path_or_buf = './TIC_271698144/TIC_271698144.csv',overwrite=True)

# %%
d = n_lc.truncate(before = [1332.3], after = [1332.45])
d1= d.remove_nans()

# %%
#d1.to_csv(path_or_buf = './TIC_271698144/TIC_271698144.csv',overwrite=True)

# %%
d1.plot()
#plt.savefig("./TIC_271698144/TIC_271698144_zoomed.pdf")

# %%
#lc.plot()
#plt.xlim(1518.75,1519)
#plt.savefig("flare_1403938_zoomed")
# Out:
# (1518.75, 1519.0)

# %%
#lc.plot()
#plt.xlim(1527,1528)
#plt.ylim(500,650)
#plt.savefig("flare_1403938_zoomed2")
# Out:
# (500.0, 650.0)
