# %%
import lightkurve as lk
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
search_result = lk.search_lightcurve('TIC 1403938')
search_result[0]
# Out:
# SearchResult containing 1 data products.
#
#  #     mission     year author exptime target_name distance
#                                   s                 arcsec
# --- -------------- ---- ------ ------- ----------- --------
#   0 TESS Sector 08 2019   SPOC     120     1403938      0.0

# %%
lc = search_result[0].download()
# Out:
# WARNING: UnitsWarning: 'BJD - 2457000, days' did not parse as fits unit: At col 0, Unit 'BJD' not supported by the FITS standard.  If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'e-/s' did not parse as fits unit: At col 0, Unit 'e' not supported by the FITS standard.  If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# ...

# %%
#lc.PDCSAP_FLUX.plot()
#plt.savefig("./TIC_353898013/flare_353898013")

# %% [markdown]
# # remove outliers and nan values
#
# -

# %%
#remove outliers and nan values

lc1 = lc.remove_nans()#.remove_outliers()
#print(lc)
lc1 = (lc1["time", "flux", "flux_err"])
print(lc1)
# Out:
#        time             flux         flux_err
#                     electron / s   electron / s
# ------------------ -------------- --------------
# 1517.8712817429162  5.2685828e+02  7.8678985e+00
# 1517.8726706661466  5.2736395e+02  7.8580666e+00
# 1517.8740595898437  5.1299261e+02  7.8283324e+00
# 1517.8754485135398  5.3038721e+02  7.8403864e+00
# 1517.8768374367698  5.2147510e+02  7.8162708e+00
# 1517.8782263604664  5.2858441e+02  7.8284259e+00
# 1517.8796152836978  5.3236621e+02  7.8168135e+00
# 1517.8810042073935  5.3079492e+02  7.7959538e+00
#  1517.882393130623  5.3830231e+02  7.8028336e+00
# 1517.8837820543195  5.3178174e+02  7.8063855e+00
#                ...            ...            ...
# 1541.9922170425866  5.3621063e+02  6.7638965e+00
# 1541.9936059024878  5.3262518e+02  6.7553120e+00
#  1541.994994762854  5.3654944e+02  6.7761097e+00
# 1541.9963836227541  5.3785724e+02  6.7730455e+00
# 1541.9977724831203  5.3031152e+02  6.7638354e+00
# ...

# %%
lc1.plot()
# Out:
# <AxesSubplot:xlabel='Time - 2457000 [BTJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %%
#normalize

n_lc = lc1.normalize()
n_lc.plot()
# Out:
# <AxesSubplot:xlabel='Time - 2457000 [BTJD days]', ylabel='Normalized Flux'>

# %%
###lc.to_fits(path='./TIC_233547261/TIC_233547261.fits', overwrite=True)

# %%
#n_lc.to_csv(path_or_buf = './TIC_1403938/TIC_1403938.csv',overwrite=True)

# %%
d = n_lc.truncate(before = [1518.75], after = [1518.95])
d1= d.remove_nans()

# %%
#d1.to_csv(path_or_buf = './TIC_1403938 (2nd_trial)/TIC_1403938.csv',overwrite=True)

# %%
d1.plot()
#plt.savefig("./TIC_1403938 (2nd_trial)/TIC_1403938_zoomed")

# %%
#lc.plot()
#plt.xlim(1518.75,1519)
#plt.savefig("flare_1403938_zoomed")
# Out:
# (1518.75, 1519.0)

# %%
#lc.plot()
#plt.xlim(1527,1528)
#plt.ylim(500,650)
#plt.savefig("flare_1403938_zoomed2")
# Out:
# (500.0, 650.0)

# %%
#masking

from astropy.table import Table
file = ascii.read("./TIC_1403938/TIC_1403938.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [29], in <cell line: 4>()
#       1 #masking
#       3 from astropy.table import Table
# ----> 4 file = ascii.read("./TIC_1403938/TIC_1403938.csv")
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'read'
