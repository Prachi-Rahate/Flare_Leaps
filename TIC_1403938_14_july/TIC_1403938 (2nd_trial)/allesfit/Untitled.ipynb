# %%
import matplotlib.pyplot as plt
from astropy.io import ascii
from astropy.table import Table

# %%
file = ascii.read("TIC_1403938.csv")

# %%
print(file)
# Out:
#        time           flux      flux_err
# ------------------ ---------- -----------
# 1518.0004516308315 0.96756577 0.014042562
# 1518.0018405540623 0.96690142 0.014027519
#  1518.003229477759 0.97837502 0.014021645
# 1518.0046184014552 0.98076922 0.014026793
# 1518.0060073246852 0.98617303 0.014031841
# 1518.0073962483814 0.98017889 0.014024708
# 1518.0087851720784  0.9529779 0.013977977
#  1518.010174095309  0.9666841 0.014018054
# 1518.0115630190046 0.99634326 0.014046706
# 1518.0129519427007  0.9834857  0.01399993
#                ...        ...         ...
#  1518.975475527268  1.0271956 0.012766085
#  1518.976864449102  1.0261999  0.01279326
# 1518.9782533714008  1.0235894  0.01276145
# 1518.9838090592004  1.0543705 0.012817987
# 1518.9851979810342  1.0658921 0.012838558
# 1518.9921425911332  1.0617974 0.012813624
# 1518.9935315129662  1.0674605 0.012831125
# 1518.9949204348004  1.0494989 0.012799138
# 1518.9963093566346  1.0581393 0.012822697
# 1518.9976982789333  1.0493972 0.012777127
# 1518.9990872007668  1.0671529 0.012820904
# Length = 598 rows

# %%
x = file["time"]
y = file["flux"]

# %%
plt.scatter(x,y)
